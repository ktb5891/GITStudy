# %% [markdown]
# # 통계모델 기본

# %% [markdown]
# ## 통계모델

# %% [markdown]
# #### 데이터에 적합하게 구축된 확률모델

# %% [markdown]
# ## 통계모델을 만드는 방법

# %% [markdown]
# ### 종속변수와 독립변수

# %% [markdown]
# 종속변수 : 어떤 요인에 종속된 변수, 어떤 변화에 응답하는 변수
#
# 독립변수 : 흥미있는 대상의 변화를 설명하는 변수, 모델 내의 다른 대상에 영향을 받지 않는 변수

# %% [markdown]
# ### 파라메트릭 모델

# %% [markdown]
# 가능한 한 현상을 단순화해서 소수의 파라미터만 사용하는 모델

# %% [markdown]
# ### 논파라메트릭 모델

# %% [markdown]
# 소수의 파라미터만 사용한다는 방침을 취하지 않는 모델

# %% [markdown]
# ### 선형모델

# %% [markdown]
# 종속변수와 독립변수의 관계를 선형으로 보는 모델

# %%
from IPython.display import Image
Image("img/liner_nonliner_model.png")

# %% [markdown]
# ### 변수 선택

# %% [markdown]
# 모델에 사용될 독립변수를 고르는 작업

# %%
Image("img/variance_select.png")

# %% [markdown]
# ### Null 모델

# %% [markdown]
# 독립변수가 없는 모델

# %% [markdown]
# ### 검정을 이용한 변수 선택

# %%
Image("img/Beer_model.png")

# %% [markdown]
# 귀무가설 기각 -> 기온에 대한 계수가 0이 아니라고 판단 가능 -> 모델에 기온이라는 독립변수 필요
#
# 대립가설 기각 -> 모델은 간단한 쪽이 좋다는 원칙 -> 변수(기온)를 모델에서 제거

# %% [markdown]
# ### 정보 기준을 이용한 변수 선택

# %% [markdown]
# 아카이케 정보 기준 (AIC)를 자주 사용

# %% [markdown]
# ### 통계모델을 만들기 전에 분석의 목적을 정한다.

# %% [markdown]
# #### 실제 코드를 작성하기 전에 분석의 목적을 결정하고 데이터를 수집하여 모델링하는 것이 중요

# %% [markdown]
# ## 데이터의 표현과 모델의 명칭

# %% [markdown]
# ### 정규선형모델

# %% [markdown]
# #### 종속변수가 정규분포를 따르는 것을 가정한 선형모델

# %% [markdown]
# ### 회귀분석

# %% [markdown]
# 정규선형모델 중 독립변수가 연속형 변수인 모델

# %% [markdown]
# ### 다중회귀분석

# %% [markdown]
# #### 회귀분석 중에서도 독립변수가 여러 개 있는 것

# %% [markdown]
# #### 독립변수가 1개인 회귀분석 : 단일회귀분석

# %% [markdown]
# ### 분산분석

# %% [markdown]
# #### 정규선형모델 중에서 독립변수가 카테고리형 변수인 모델

# %% [markdown]
# 독립변수가 1종류 : 일원분산분석
#
# 독립변수가 2종류 : 이원분산분석

# %% [markdown]
# ## 파라미터 추정 : 우도의 최대화

# %% [markdown]
# ### 우도

# %% [markdown]
# #### 파라미터가 정해져 있을 때 표본을 얻을 수 있는 확률

# %% [markdown]
# ### 우도함수

# %% [markdown]
# #### 파라미터를 넘겨서 우도를 계산할 수 있는 함수

# %% [markdown]
# ### 최대우도법

# %% [markdown]
# #### 우도나 로그우도의 결과를 최대로 하기 위한 파라미터를 추정할 때 사용하는 방법

# %% [markdown]
# ## 파라미터 추정 : 손실의 최소화

# %% [markdown]
# ### 손실함수

# %% [markdown]
# #### 파라미터 추정을 할 때 손실을 최소화하는 목적으로 사용

# %% [markdown]
# ### 잔차

# %% [markdown]
# #### 실제 종속변수의 값과 모델을 이용해서 계산한 종속변수의 추정치와의 차이

# %% [markdown]
# ### 잔차의 합을 그대로 손실의 지표로 사용할 수 없는 이유

# %%
Image("img/residual_problem.png")

# %% [markdown]
# ### 잔차제곱합

# %% [markdown]
# #### 잔차를 제곱해서 합계를 구한것
# 잔차제곱합을 사용하여 잔차의 합이 가지는 문제를 해결

# %% [markdown]
# ### 최소제곱법 (OLS)

# %% [markdown]
# #### 잔차제곱합을 최소로 하는 파라미터를 채용하는 방법

# %% [markdown]
# ## 예측 정확도의 평가와 변수 선택

# %% [markdown]
# ### 적합도와 예측 정확도

# %% [markdown]
# 적합도 : 가지고 있는 데이터에 대해 모델을 적용했을 때 들어맞는 정도
#
# 예측 정확도 : 아직 얻지 못한 데이터에 대해 모델을 적용했을 때 들어맞는 정도

# %% [markdown]
# ### 과적합(오버피팅)

# %% [markdown]
# #### 적합도는 높은데, 예측 정확도가 낮아지는 경우

# %% [markdown]
# ### 변수 선택의 의의

# %% [markdown]
# 필요 없는 독립변수를 제외하는 것만으로도 예측 정확도가 높아질 가능성이 있음.
#
# But, 필요 없는 독립변수를 추가해도 적합도가 높아짐

# %% [markdown]
# ### 훈련 데이터와 테스트 데이터

# %% [markdown]
# 훈련 데이터 : 파라미터 추정에 사용되는 데이터
#
# 테스트 데이터 : 일반화 오차를 평가하기 위해 파라미터 추정을 할 때 사용하지 않고 남겨둔 데이터

# %% [markdown]
# ### 교차검증

# %% [markdown]
# 교차 검증(Cross Validation,CV) : 데이터를 일정한 규칙에 따라 훈련 데이터와 테스트 데이터로 나누어 테스트 데이터에 대한 예측 정확도를 평가하는 방법
#
# 리브-p-아웃 교차검증 : 가지고 있는 데이터에서 p개의 데이터를 추출하고 남은 데이터를 테스트 데이터로 사용하는 방법
#
# K겹 교차검증 : 가지고 있는 데이터르 K개의 그룹으로 나눈 후 그 그룹 중에서 하나를 추출해 테스트 데이터로 사용. 이것을 K번 반복해 예측 정확도의 평균값을 평가값으로 사용

# %% [markdown]
# ### 아카이케 정보 기준(AIC)

# %% [markdown]
# #### AIC = -2*(최대로그우도 - 추정된 파라미터 수)

# %% [markdown]
# AIC가 작을수록 좋은 모델
